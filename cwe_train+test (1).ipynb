# %%
# !pip install tokenizers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tokenizers
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 4.3 MB/s
# Installing collected packages: tokenizers
# Successfully installed tokenizers-0.13.1

# %%
#importing the libraries
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import random
import io
from google.colab import files

# %%
#reading, loading the dataset
with open('cwe-train.txt', 'r') as f:    
   text_data=f.read()

# %%
text_data
# Out:
# 'chikale vinogile fana viya wanhu wochikala habung\'huke imisi, si kwa umelo na ung\'waji na unyolodo na uwashelati na ndwagi hebu migongo. one muhapula chinhu chochose kwa zina jangu nizamtendelani. yesu kamulongela petili, "bweleza zele jako muna iyala. "ufalume wa kuulanga ulinga vino. niye mulala mulangulizi, nokwandikila weye gayo mulondwa wangu yonikulonda muna ikweli. nomulongelani ukweli, munhu yoyose yohauhokela ufalume wa mulungu fana mwana mdoododo, hezakwingila muna ufalume uwo ng\'o!" iyo ni mfalume wa siku zose na hadanganika na hawoneka na yeli mulungu yaidumwe. one munhu yoyose yahawa na nzala, kolondeka yaje ukaye yake, muladi vondamuiting\'hane sekeyatagusigwe. lelo kwa mbuli ziya zimwandike kuwa. maabaho msenga wa kuulanga wekaidi kaitowa mhalati yake na chinhu fana mulima mkulu woukwaka moto chasigwa muibahali selusi ya bahali igaluka damu. msede yahandile misavu niiyo mwihi kugozela uhelelo wa isi na waja wogobola ni wasenga wa kuulanga. wouutendile uwoneke kwa wanhu wose. kwaviya mweye mumfunyila umoyo munhu yokwiza na kompeta yesu imwenga kufosa yesu wochimpeta, hebu yomumuhokele muhe mbasakanyo kulawa muhe yelile yoyomuhokele, na mbuli inogile mbasakanyo kufosa ija yomuihokele kulawa kumwetu. kaidi hawaja chinhu chilawile kudisoko mbaka wachisunhe teng\'hu. "ivo mfalume agilipa siyalemile bule malaguso kulawa kuulanga kwa mulungu. kumbukeni kuwa chila munhu mwene kutenda yanogile, yawe mtumwa hebu munhu yoyailegehe, kezahokela bweko jake kulawa kwa mndewa. munhu yolonga kwa ulonzi wa kwazanya, halonga na wanhu mbali wolonga na mulungu, kwaviya habule munhu yoyose yommanya. yesu na wanahina wake wakala mwiinzila, woita yelusalemu. mbali zuwa da mndewa dizakwiza fana mbavi viyokwiza, muna dizuwa ijo ulanga wizasegela kwa msindo mkulu na vinhu vose vili kuulanga vizanangigwa kwa moto, na isi na vose viliumo vizanangigwa. yesu na wanahina wake wenuka na kumsondelela. mbali malagilizo ya mulungu yoyamwing\'hile musa hayategemeya uhuwilo, ila maandiko yelile yolonga, "munhu yoyose yoyofikiza vinhu ivo vivilondeka na malagilizo kezakala kwa malagilizo yayo" maabaho wanahina wake wamuuza, "habali wafundiza malagilizo wolonga eliya kolondeka yanduse kwiza?" wakalizi wawedika, "habule munhu yoyose yoyalongile fana viyolonga munhu ino!" ndugu zangu, vinizile kumwenu simpeteleni usenga ukweli woufisike kusonhela mulungu kwa mbuli zozilondeka hebu kwa ubala wa wanhu. mulimi yatendile usang\'hano kwa kuiyoha kolondeka yawe wa mwanduso kupata chiya chotile muna umgunda wake. fana miye nosang\'hanila ludabwa lwa mwenembago kulava vinyamkela, lelo wanhu wenu wolava vinyamkela kwa udaho wa yelihi? wengi mwa iwanahina wake viwahulike, walonga, "mafundizo yano madala. wanhu wose wazanywa ng\'hani na wakala woilongela, "vino zino ni mbuli zaki? na waja wawonile yalawilile wamuwona wawasimulila viya munhu ija yakumbigwe na chinyamkela viyahonyigwe. nomulambani kuwa vondanize kumwenu sekemuniwangilize niwe mkali, kwaviya novimanya kuwa nizawakalikila waja wolonga kuwa chokala ugima wa chiisi. ivo mweye molonga, "chitogoliligwa kutenda chinhu chochose." maabaho yesu kalutanga kaidi ulung\'husesa lwa wanhu na kalulongela, "nhegelezeni mose na muvimanye. na ingawa kakala mwana wa mulungu, kaifunza kutegeleza kufosela manhesa yoyapatile. muiteganye mweye wenyewo na muwatiganye lung\'husesa lwose luja muhe yelile yamwikileni muwe wemilizi wake mgati mmwake, mudidime bumbila da wahuwila wa mulungu woyawatendile wawe wake kwa kufosela damu ya mwanage. na mweye mwiza mwizabidukigwa na tati zenu, na mami zenu, na ndugu zenu, na wakaya wayenu, na mambwiya zenu. yesu kavumbuka muna dibululu da betelehemu muna isi ya yudeya, chipindi helode viyakalile mfalume. "mwizagaya mweye wafundiza malagilizo na mafalisayo! vinikalile na mweye singazile munhu yeyose ija haja vinilondile vinhu, ndugu walawile makedoniya wanigalila chila chinhu chonilondile. nolonda kuwakumbusani mbuli ziya zilongigwe umwaka na walotezi welile na malagilizo yalawile k ...

# %%
vocab = sorted(set(text_data)) 
vocab_to_int = {c: i for i, c in enumerate(vocab)}    
int_to_vocab = dict(enumerate(vocab))    
encoded = np.array([vocab_to_int[c] for c in text_data], dtype=np.int32)

# %%
#reference: https://towardsdatascience.com/word-and-character-based-lstms-12eb65f779c2 
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text_data) - maxlen, step):
    sentences.append(text_data[i : i + maxlen])
    next_chars.append(text_data[i + maxlen])

# %%
print("Number of sequences:", len(sentences))
# Out:
# Number of sequences: 201131

# %%
no_of_characters = sorted(list(set(text_data)))
print("Total characters:", len(no_of_characters))
# Out:
# Total characters: 32

# %%
X = np.zeros((len(sentences), maxlen, len(no_of_characters)), dtype=np.bool)
Y = np.zeros((len(sentences), len(no_of_characters)), dtype=np.bool)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
X.shape
# Out:
# (201131, 40, 32)

# %%
Y.shape
# Out:
# (201131, 32)

# %%
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        X[i, t, vocab_to_int[char]] = 1
    Y[i, vocab_to_int[next_chars[i]]] = 1

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(no_of_characters))),
        layers.LSTM(4),
        layers.Dense(len(no_of_characters), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer,metrics=['accuracy'])

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
#reference: https://medium.com/deep-learning-with-keras/char-level-text-generation-with-an-lstm-model-e55ba7ff18c2
epochs = 10
batch_size = 128

for epoch in range(epochs):
    model.fit(X, Y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text_data) - maxlen - 1)
    for diversity in [0.5]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text_data[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(no_of_characters)))
            for t, char in enumerate(sentence):
                x_pred[0, t, vocab_to_int[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = int_to_vocab[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 1572/1572 [==============================] - 36s 21ms/step - loss: 2.1863 - accuracy: 0.3369
#
# Generating text after epoch: 0
# ...Diversity: 0.5
# ...Generating with seed: "la da pasaka na kalagiliza damu imizigwe"
# ...Generated:   usa musabuna mwe mula sangugola kuna si, wale mwa ga wa musa muya wa waka, wanga kumwa mula na hana lumula wa muluna yangu mbeha wala na imwa, mumwela nola muyongu kulalabela yele wana kulangwa kulumwa kusa wangu kwana mbuli mwa mumwa wana yama wangili na chike mani chini wa chila ni mula na waga wela muni muna yolamwa mwa mwa za kana walila wosa mulu wona mwengila kamwa wa yalingu musa kuna kula
#
# 1572/1572 [==============================] - 28s 18ms/step - loss: 1.9467 - accuracy: 0.3819
#
# Generating text after epoch: 1
# ...Diversity: 0.5
# ...Generating with seed: " yose na yeye mwenyewo kwa nzila ya chil"
# ...Generated:  a kusa kune muni kana wa wanhe mundu muvige ving'hesa yana muleng'hale nhu kasi wandu mana mwa ningi kuya mwa yoa wangu ilana muni vimwa mumula mwa mnha ita vina wa umwa wanhu mwaza ya iwa wa wani hanza yata dilanga yani mulu. hana kulaya wa ye. kukunina mwa mulunhu kakungu luna muno muluna wa wa kuhangu kulakeli yela chila yana kwa nane wa wa mwane yali kuni ya kulalane wa kumuni ya wa malimu mwa
#
# 1572/1572 [==============================] - 28s 18ms/step - loss: 1.9145 - accuracy: 0.3901
#
# Generating text after epoch: 2
# ...Diversity: 0.5
# ...Generating with seed: "g'hani isi inogile ng'hani, isi ya kuula"
# ...Generated:  lulana kachili ya mung'ha wa wa kulunile mulune na na na na kune na mwandilendi nile mwa kulunhu kulumya mwa mwa utela kungu wa mwa hangu mulale muno ya wana wa yetu kasi dolita kulengo mbele hammwe wa kumbaliga kunile hamwa wa wa visekangu kayang'ha ya chiye mwa kuna wangile mwa muwa mwa kwa mumweng'hangu hamula wa kuneng'ha muna mwa mba kuna kuna wangu na muwa kasi wamuna hana mumungu ya mungu k
#
# 1572/1572 [==============================] - 28s 18ms/step - loss: 1.8988 - accuracy: 0.3953
#
# Generating text after epoch: 3
# ...Diversity: 0.5
# ...Generating with seed: "leni lufo, yasaguligwe haswa kusang'hana"
# ...Generated:   mwa munila kakula habase chilela kawaliwe mumwa wa mulengu mwa wana muna muna yaliguli wa muna mwele muni iya dongu kuni waka kalani kulana mane kwa mululu kulila ya mulangila mulelo noguli mulana waku na mulisa na weli, kulele mwa mulela yanha kuna wanhu wangu mwahi musa ing'ha malangu ingu wa kusa chingili iya, na wa kwa na kululivihi wanhu ngu imula yangu yakangu mulongu na chingu, wa kahangu
#
# 1572/1572 [==============================] - 28s 18ms/step - loss: 1.8883 - accuracy: 0.3980
#
# Generating text after epoch: 4
# ...Diversity: 0.5
# ...Generating with seed: "kusang'hana sang'hano ino, mbali udaho w"
# ...Generated:  ama wa mwa kamana kululo na mwa wa laso mulile mwalake wa wa zingu mbwa kuno wa, una na ina wa mwa wawa wa yaliku kusa kumila yaviha mwengo wanila mbali mwa mbela kulumulung'hala hangu mwa mwa vimumwa waya na wa wana kuya na mwa chilulila mwilila kune mali hana wa wangila kakula wa kaya na kumani, muwa chilengu wa wangu kalata waililo wamuvigali kuhala yangu. ikulo kulali na kwambale kase chili ka
#
# 1572/1572 [==============================] - 29s 18ms/step - loss: 1.8818 - accuracy: 0.3954
#
# Generating text after epoch: 5
# ...Diversity: 0.5
# ...Generating with seed: "ungu hamwande. mweye molola vinhu voviwo"
# ...Generated:   mwangu kukisa kuna mwau. chinili wangila kungu kunimungu bali wanhu mulula kumundongu kayendihi kungo kungu muna muni wakungu mbala wangu mwa na na yanya mungu kasa mutangu muna wa ya wangu wa kazingele mwa kana kuni manigalengu na mungu mululono yangu na na mwa muli na kululengu wanda na mwa muna wanhu. na wani mungula kumandela mululilo wa waka muna munhela mani kasi mukase kowanhu wa yaula inh
#
# 1572/1572 [==============================] - 29s 18ms/step - loss: 1.8762 - accuracy: 0.3957
#
# Generating text after epoch: 6
# ...Diversity: 0.5
# ...Generating with seed: "e na mwiguta. mweye mung'hali hamuvimany"
# ...Generated:  e vingile. mungu na na muluna na mulatila mungu kuwanile mwa wang'hela mwa wawa waya wa kukuli kune mwandilido kana chila chila mbala na muni wa kumala, mwamanhu hakula kulo munhu mbale wang'helo, yana muna kuto kusa wa waka wanda mwangu wandila kungu vimungilo kulinhu mbalo mungile kuwamungu wanhu hakula kwa mwa imulonhu ya mwa na wang'ha vilungu kulula wangu welemzi wesa mbo kusa kana kana wangw
#
# 1572/1572 [==============================] - 29s 18ms/step - loss: 1.8712 - accuracy: 0.3960
#
# Generating text after epoch: 7
# ...Diversity: 0.5
# ...Generating with seed: "kusondelela tamaa zihile zimukalile nazo"
# ...Generated:   kadingu mwama muni wa kuna mungu wa kuno wamalila muni wa ya mokuli na yangu na mwangile kuziya kase yangu mona wandi kumulila na ni walimulila mulile mana yehana kululinga na nhalazi mulali na wangu wa kwoli mwona mbale kukulo pali vinhela kulasa kungu iya keli kuwamwe kusi momwi kusa una mwawa ulula ikali mwawe mungwa kuni kuluhabuma waka kuna na kuyeli mungu kuna kululi na na kulela kulengu wa
#
# 1572/1572 [==============================] - 29s 18ms/step - loss: 1.8658 - accuracy: 0.4019
#
# Generating text after epoch: 8
# ...Diversity: 0.5
# ...Generating with seed: "mweye. kwandusila sambi sekeung'we mazi "
# ...Generated:  na wangu chingu kumulela na mwa kwa mwangu kuna wanha mbula wawa mwaka kose kulangwa kulani chilongu kawanhu waka mbotele kumuna simulili wa mbang'ha kona mung'hale wa na ya chisa yangu malingu manya wako na ving'hale kusa wa musa kulingu wa kuwona mwani kela na kumulingu kuna kuni wa kwa wa wa walumba muna na mungu mang'ha wang'hani ving'hangu kuma wangu msa mulang'hatita muluke kululeya yawe kuk
#
# 1572/1572 [==============================] - 28s 18ms/step - loss: 1.8609 - accuracy: 0.4059
#
# Generating text after epoch: 9
# ...Diversity: 0.5
# ...Generating with seed: "mibalati na wezamuwamba mumsalaba, mbali"
# ...Generated:   kuna wana wana makule kuwa sangu mwilwo mna kwa wana wa na kumuliga na mung'ha na wa mula mulonhu wanhu wangu wangu kwa kusaka mwana mulungu ya na wa kuyelo mwa kumwa ya kuilengu kuna kumwingu kula kahangu kulangu kulenda kulungwa na wa yawa na mwongu kuya muna mana yanido manile kulaula kuwamani mwawa na muna ulanda kana kuyanya mwina mwanda muni wang'hala mulule kusi mwikundu na ya wanhu mukulo

# %%
#reading, loading the dataset
with open('cwe-test.txt', 'r') as f:    
   test=f.read()

# %%
test
# Out:
# 'sang\'hanileni vinogile chila nzila imwili nayo, kwaviya siku zino ni za wihi. nhondo iyo itangigwa usungu, selusi ya mazi yawa masungu, wanhu wengi wang\'wile mazi yayo wadanganika kwaviya yagaluka masungu. kukala na minyong\'onyo muna ulung\'husesa lwa wanhu. mbali ingawa kuna wanhu wengi woigoda fana viya wanhu wa isi, na niye nizatenda ivo ivo. vino kumwenu kuna munhu mtamu? lung\'husesa lukulu lwa wanhu luiting\'hana mbaka wanhu wakala woibojoga. mbali deng\'heleleni kwingila muna yamagayo fana chilisito viyagaiye, muladi mudeng\'helele ng\'hani utunhizo wake vondaugubuligwe. ndugu zangu, sigesa kuwa nipata gweko. kwaviya ugima ni bola kufosa ndiya na lukuli ni bola kufosa viwalo. ndugu zangu muhamuwona munhu kabananga, mweye womulangulizigwa na muhe wa mulungu mzumeni munhu iyo kwa uhole, mbali mweye wenyewo muiteganye muladi sekemugezigwe. maabaho nikumbuka chiya chiyalongile mndewa, \'yohana kabatiza kwa mazi, mbali mweye mwizabatizigwa kwa muhe yelile.\' wambwiya zangu, simwandikilani ndagilizi ya sambi, mbali ndagilizi ya umwaka yomukalile nayo kusongela mwanduso. muhokeni hela iyo iyeli nayo, mwing\'heni ija yeli na masanduku longo ya hela. nokumbuka uhuwilo wako wa kweli, uhuwilo uyakalile nawo wau yako loisi na mamiyake yako eunike. iviya na mulawi viyafosile haja na kumuwona munhu yoyatowigwe, nayo kagwaza. yesu chilisito ni ija ija igolo na diyelo na siku zose. ivo, fana viya lukuli bila muhe ludanganika, ivo ivo uhuwilo bila ya sang\'hano udanganika. wanhu wamwenga walonda kumgeza yesu, ivo wamulonda yatende mauzauza kulagusa kuwa kalawa kuulanga. "yodahika vilihi munhu kwingila mgati mwa kaye ya munhu imwenga yeli na ludabwa hamala baho kusola vinhu vake, na sekeyanduse kumfunga munhu iyo yeli na ludabwa? walonga, "lelo hachilonda wakalangama kaidi? hakwizakuwa chinhu chochose kaidi chonda chiduwiligwe na mulungu. maabaho vinikalile nolola nihulika mhungu koguluka hagati kuulanga kolonga kwa dizi kulu, "wezagaya! niye nomulongelani, hata mfalume solomoni muna utunhizo wake wose, hadahile kuyawazigwa vinogile fana dimwe muna yamaluwa yano. muumulomo uja uja molawa nhogolwa na duwilo. wanhu wamwenga wasigale iwawo hawakomigwe na mahulo yayo, hawasamhile sang\'hano zowazitendile kwa makono yawo wenyewo, na hawalekile kutambikila mbeho zihile na nyang\'hiti za milungu za zahabu na hela na shaba na mabwe na mibiki na vinhu viya havidaha kulola hebu kuhulika hebu kugenda. na mweye vondamuhulike ng\'hondo na mbuli za ng\'hondo, sekemudumbe. baho wayahudi wandusa kuiuzagiza kwa ludoko, "vino munhu ino kodahaze kuchigha lukuli lwake chije?" cheye hachigeza kaidi kuigoda wenyewo haulongozi wenu. wanhu wawo wolawa kumwetu mbali hawawile wa kumwetu, kwaviya one wawile wa kumwetu, wahakalile hamwe na cheye, mbali viwachilekile ilagusa kuwa hawawile wa kumwetu. chivimanya kuwa malagilizo ya mulungu yoyamwing\'hile musa yanoga one yahasang\'haniligwa fana viilondeka. chiwona vinoga kwa muhe yelile na kwa cheye chileke kumtwikani mbahasha zizamile kufosa yano yomulondeka kuyamanya. pilato kawauza, "vino katenda chinhu gani chihile?" chila munhu yomwihila muhuwilaa miyage ni mkomaji, na movimanya kuwa habule mkomaji yeli na ugima wa siku zose. mafalisayo wamwenga wowakalile muna lung\'husesa luja wamulongela yesu, "mfundiza, wazume wanahina wako wanyamale!" "mwahatosa, sekemuwe fana viya wadelenya! yesu kolonga, "tegelezeni, nokwiza sambi!" vondanize, nizamgweka chila munhu kwa sang\'hano yake iyatendile. nivimanya kukala na vinhu vidodo na nivimanya kukala na vinhu vingi. ivo yohana kahita chila hanhu habehi na lwanda lwa yolodani. wanhu iwadanganike vondawazilibuke, hawezasola wala kusoligwa, wezakuwa fana wasenga wa kuulanga. na yesu kakula muna ubala na ichimo, na kumnogeza mulungu na kuwanogeza wanhu iviya. kawalongela, "hiteni kuchibululu chili kuulongozi. hata nyele za mmatwi yenu zipetigwa zose. kwaviya muhawa na nhunya izo zose kwa wingi, zizamdahizani muwoneke mofaya na kupata kuinzana na umanyi wenu kusonhela mndew ...

# %%
vocab_test = sorted(set(test)) 
vocab_to_int_test = {c: i for i, c in enumerate(vocab_test)}    
int_to_vocab_test = dict(enumerate(vocab_test))    
encoded_test = np.array([vocab_to_int_test[c] for c in test], dtype=np.int32)

# %%
encoded_test
# Out:
# array([25,  9, 22, ...,  9,  7,  0], dtype=int32)

# %%
maxlen = 40
step = 3
sentences_test = []
next_chars_test = []
for i in range(0, len(test) - maxlen, step):
    sentences_test.append(test[i : i + maxlen])
    next_chars_test.append(test[i + maxlen])

# %%
print("Number of sequences:", len(sentences_test))
# Out:
# Number of sequences: 20559

# %%
test_char = sorted(list(set(test)))
print("Total characters:", len(test_char))
# Out:
# Total characters: 32

# %%
X_test = np.zeros((len(sentences_test), maxlen, len(test_char)), dtype=np.bool)
Y_test = np.zeros((len(sentences_test), len(test_char)), dtype=np.bool)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
for i, sentence in enumerate(sentences_test):
    for t, char in enumerate(sentence):
        X_test[i, t, vocab_to_int_test[char]] = 1
    Y_test[i, vocab_to_int_test[next_chars_test[i]]] = 1

# %%
model_test = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(test_char))),
        layers.LSTM(5),
        layers.Dense(len(test_char), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model_test.compile(loss="categorical_crossentropy", optimizer=optimizer,metrics=['accuracy'])

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
X_test.shape
# Out:
# (20559, 40, 32)

# %%
Y_test.shape
# Out:
# (20559, 32)

# %%
epochs = 10
batch_size = 128

for epoch in range(epochs):
    model_test.fit(X_test, Y_test, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(test) - maxlen - 1)
    for diversity in [0.5]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = test[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(test_char)))
            for t, char in enumerate(sentence):
                x_pred[0, t, vocab_to_int_test[char]] = 1.0
            preds = model_test.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = int_to_vocab_test[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print()
# Out:
# 161/161 [==============================] - 3s 19ms/step - loss: 2.2953 - accuracy: 0.3058
#
# Generating text after epoch: 0
# ...Diversity: 0.5
# ...Generating with seed: "vo ndugu zangu funyeni umoyo mbaka mndew"
# ...Generated:  a mwa ko ma "wa na winini ha kiya ka gu ma ya imo nha mu ka ka ge mula ngu se mwa la na wa ga wani  wa wa ho wa ma ka  gitenga wa we wa ke huma kena ngwena wana ku wula mila ka wa ya sala wa wa iyila nga ha ka mwe ka mu wa va ya gunike ila we ha ya ka mungugi we mi wa nga. ha ka ya ka male wa cha ya munu wa la mule la wengu ka miniwena wa  wa wa wa kanha u za kena ma gu wa wa mukuwa va ya ma yala
#
# 161/161 [==============================] - 3s 19ms/step - loss: 2.1341 - accuracy: 0.3327
#
# Generating text after epoch: 1
# ...Diversity: 0.5
# ...Generating with seed: "nanzi,' yezakuwa kweli. "na mtumwa ija y"
# ...Generated:  a we he ni kuna ku ku na mu mulana za na mu mulu ka we mwa mu ka wa munhali wa kanga ya na munge wi mi wa wabu ya ka wa mungu wa mumu gula mwa ka melimwa wa wa ka kala nga wa ha ha wa kungenga mwa ka kula ka mwa kuingulila wa ki. mwe mu wa ki na mwila no mulo kula halanga mila na ku ka ko ya ku wa wala muwa wa kuwa mu mumwe na mila ku na mumuna kulila mu wo wa nala kengita wenha cgu mula kana mula
#
# 161/161 [==============================] - 3s 19ms/step - loss: 2.0760 - accuracy: 0.3449
#
# Generating text after epoch: 2
# ...Diversity: 0.5
# ...Generating with seed: " kamulekela balaba kulawa mchifungo. mba"
# ...Generated:   muline mulingula miso ya ya vala muuna sinhamulawa wa mwa mula ya wa wa kula ha mu muli komulelawa wa kwa kili mwi na kawa ngalu kini kula ke mwi kula gulengumwa iwa ka wa ba ka wa wokulilila mulo kula mwa wa kalulana mwa kuna no mwa muna we wa wi vimwino mulongulila wo kuwa wa ku ka ku wangusa ka wangula kula wa mili kengule mulamula wonila ya ya kilonge mula kule ma kulana wa wana wa kinhala na
#
# 161/161 [==============================] - 3s 19ms/step - loss: 2.0460 - accuracy: 0.3542
#
# Generating text after epoch: 3
# ...Diversity: 0.5
# ...Generating with seed: "omwing'ha hewela mulungu. ivo mwenevale,"
# ...Generated:   wo ku nenganguliwila nimola wa nhileli kwa na na zi wa mungila chisangelala male mu ya na vinga ngula ka kunga ku wa mbululabawe mwa mbolanga mwa mula mwangulo we ya kuka wa wa mula wa mwingongula ha vimu wa mulenhi munga nhekamwala mana mulanga kula mula ya hula kagunga wa kala muwa kilile mu ka kula mula muna wa ba mulala we kala kulo ya ya mana mu wa kalanga mwo wa wa kala iya ma kalisu muwana
#
# 161/161 [==============================] - 3s 19ms/step - loss: 2.0268 - accuracy: 0.3570
#
# Generating text after epoch: 4
# ...Diversity: 0.5
# ...Generating with seed: "aguligwe kwa ulondo wa mulungu kuwa mtum"
# ...Generated:  ule, mu wumunda na kale na na wala wa mwa kagali mwa mwa wani wa mundilongela kwa mungata mwa na wata mwa manda kaye wa wa mu huna na kala haza wang'huna za kuta kalalule malamwa ku ya vunga kulanga wandi vi vina wa zana kulawalili kawa kalasili. na kunge muna kalo una wa kulu ya yaya ha nda kulesanda mwa chiwa wa wa kulanga mwau kulu ngalengwa mula nandina kala cha vingulinga kalina mwa kangulo k
#
# 161/161 [==============================] - 3s 19ms/step - loss: 2.0116 - accuracy: 0.3629
#
# Generating text after epoch: 5
# ...Diversity: 0.5
# ...Generating with seed: "ho wawalekelela wahite. kuna mbasakanyo "
# ...Generated:  na wa mule kala kula nhu wa lumwana mwang'hi wa kana no na wa ile wunga wa vila na kulana nanhi wa kili kelonga mwa kulili su mwa na guna wa ka mulu yo kimuwe, mulaziya wa yenda kilingu na kawa munda ya manhingu wa ku na mawa kala hu kula mawa kungange na, vina kuwengelo munda kundi. mila muno wa muulo wa wandiya kuya ya kulangu na kalawa muwa mwa wa isi kulamundila na ngiya wa nha vika wana kelin
#
# 161/161 [==============================] - 3s 19ms/step - loss: 1.9980 - accuracy: 0.3658
#
# Generating text after epoch: 6
# ...Diversity: 0.5
# ...Generating with seed: "a uko, hamwe na ndugu zake na mambwiya z"
# ...Generated:  a yano hu ina kuwu ya mulokula mululu mula na no kundo cha yawa yaso welangula mumula, kwa mundila kwa kwa muno kulalilo muna uwa kala huwe kase yandigungu wa wa wawa huwa kosa mwasila kulanda mwa kwa mulu muna viya chila kulililinga mulenha yuta kwa kano kala su mwa kula imizo musila mana kawa wa munga wa kolilike na mungu wena chomwa kulangonga wuse kwa we kwando kuna yale wana mule ya mangumuli
#
# 161/161 [==============================] - 3s 19ms/step - loss: 1.9838 - accuracy: 0.3721
#
# Generating text after epoch: 7
# ...Diversity: 0.5
# ...Generating with seed: "lungu, habule munhu yadahile kwingila mu"
# ...Generated:   wa kunga yoyo mu, kumwa kau wa mwada wawa na ya kawe wa maimulo mwanga wa wa kulu malangeni zida na na kayande kunhe walo wa kola wa muluselile kulanga mano mawa mundi wa kula yolandi wana wowa ya wane usimila yalila mwe mule mwu ni wa kola wa wa mano mwanga sa wa muno chana wa, chanhiha wa mwa muwa wanga mulu kalumula mulu vida vilo na wela na kala mwa kula. na wanga mangu viya kowa isola wo mul
#
# 161/161 [==============================] - 3s 19ms/step - loss: 1.9716 - accuracy: 0.3705
#
# Generating text after epoch: 8
# ...Diversity: 0.5
# ...Generating with seed: "haladali yili ndodo kufosa mbeyu zose zi"
# ...Generated:  la wa mwengela kula mani kula na yandi wo wa wati wa na wa katunge kamu mwa yani wola muluna kumala mana kawa waka wa wa wa wa kuchona muna wa mumulila munhi wa kulila kwa wa kawa muwa na chawa kwe yonga musa kawanga wa ndaka kwala ika munga kawa mala wa vi kange muyu uwa muwa mwa muwalili kili mu muwa mulu kulo kwolo muyo wa mila mwo kuwenga mulile na mwa wa, na mulo na mulolu kamwammwa kali mila
#
# 161/161 [==============================] - 3s 19ms/step - loss: 1.9640 - accuracy: 0.3759
#
# Generating text after epoch: 9
# ...Diversity: 0.5
# ...Generating with seed: "e ching'hali chokala kwa kulangulizigwa "
# ...Generated:  mandi munda walamsa mulile wa malana umusanga yana muna ye muna kwelau kumu kusaha kuwa kuwangela na na wa wahahana na mwa kawa mulana wa wa mulangu, kuwa viya watanoha wakala vini wazina kulana wana wakana wa wazani chundichi wawani wa kwe muwa wano wido kwa wano wamulili chana muna vuna na umumwila zana womwa chau imulangangela wa mwe yo kawa na iya walanda kusulina no wana yamu walana wana mulu

# %%
pred=model_test.evaluate(X_test, Y_test)
# Out:
# 643/643 [==============================] - 3s 4ms/step - loss: 1.9585 - accuracy: 0.3791
